# %% [markdown]
# <a href="https://colab.research.google.com/github/nsoranno/Calculus-Projects/blob/main/Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #To Start:  Make your own copy of this worksheet.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Problem 1:  Oil Slick
#
# The Google Sheet below shows the spread of an oil slick on the ocean as a function of time.  For this project, fit a function to the oil slick data, find how quickly the oil slick is growing using both algebra and the spreadsheet, and then predict when the oil slick will be growing by $1,150$ gallons per day.
#
#   a. Plot the data in the yellow cells in the spreadsheet using Desmos. Determine the function below which best matches the data for the area of the oil slick, and justify your answer.
#
#   $$  A_1 \sim b + \frac{m t_1}{s}
#   \hspace{1cm}
#   A_1 \sim \pi(b + m t_1)^k
#   \hspace{1cm}
#   A_1 \sim k e^{r t_1} + b
#   \hspace{1cm}
#   A_1 \sim b + a \sin( k \pi t_1)
#   $$
#
#   b.  Your model has three constants. Give the value of each constant and interpret what it means for the model.
#
#
#
#   c.  Using the Google Sheet, experimentally find the values for $\frac{dA}{dt}$.  You may want to fill in the table cells in columns g and h before finding the values in columns j and k.  Also, record the data in the packet.
#
#
#
#   d.  Plot the data you found for $\frac{dA}{dt}$ in Desmos.  This should be the data in the green cells in your Sheet. Determine a function below which best matches the fit, and then give the values of the constants and an explanation for their meaning in your model.
#
#   $$  \frac{d A_1}{dt} \sim c + \frac{n t_1}{q}
#   \hspace{1cm}
#   \frac{d A_1}{dt} \sim \pi(c + n t_1)^q
#   \hspace{1cm}
#   \frac{d A_1}{dt} \sim q e^{u t_1} + c
#   \hspace{1cm}
#   \frac{d A_1}{dt} \sim c + p \cos( u \pi t_1)
#   $$
#
# [ Note:  Desmos won’t let you write a fraction for the left hand side of the expressions above.  Instead, you can use a replacement for the fraction, using y_1 or d_A1 for the variable in the table and on the left hand side. ]
#
#
#   E. [ In the packet: ] Using differential rules, determine $\frac{dA}{dt}$ using the function you found in part (a) and (b).  How is this similar, or different, from what you found in part (d)?
#
#
#   F. Using both Desmos and your answer to part (E), determine when the area of the oil spread is increasing by 1,150 square feet per hour.  Include units.

# %% [markdown]
# # Spreadsheet set-up for Oil Slick Problem
#
# You'll need your own copy of the spreadsheet.  Copy the url below and paste it into a new tab.  Then, click 'File' and 'Make a Copy' to make your own copy of the spreadsheet, and paste the url into the double quotes after `my_version = `.  You can now work either in the spreadsheet below, or in the spreadsheet in the separate tab.
#
# ![image.png](data:image/png;base64,...)

# %%
original = "https://docs.google.com/spreadsheets/d/1C5sDe1Ihg0hQWv_48Pz_FqU6uAjopnL73vDlSM3R3O0/edit#gid=0"
my_version = "https://docs.google.com/spreadsheets/d/1FTZgJKVHYA0F26EyV8AQaDVbRFvsFaYOfwydjxFFhBc/edit#gid=0"
from IPython.display import IFrame
IFrame(src=my_version, width=1200, height=475)
# Out:
#         <iframe
#             width="1200"
#             height="475"
#             src="https://docs.google.com/spreadsheets/d/1FTZgJKVHYA0F26EyV8AQaDVbRFvsFaYOfwydjxFFhBc/edit#gid=0"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame(src="https://www.desmos.com/calculator/eek26dieiu", width=1200, height=875)
# Out:
#         <iframe
#             width="1200"
#             height="875"
#             src="https://www.desmos.com/calculator/eek26dieiu"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #Save your work to Github:
#
# To save your work in Github, click on 'File' and select 'Save a copy in Github'.  Your Github repository should appear automagically.  Click 'OK', and your file should be now in your Github account.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
