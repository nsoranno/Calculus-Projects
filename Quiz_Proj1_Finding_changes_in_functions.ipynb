# %% [markdown]
# <a href="https://colab.research.google.com/github/nsoranno/Calculus-Projects/blob/main/Quiz_Proj1_Finding_changes_in_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #To Start:  Make your own copy of this worksheet.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Changes in Functions
#
# In earlier projects, we found formulas for the change in area
#
# $$dA = 2s ds$$
#
# of a square $A = s^2$ when the side length was increased various amounts $ds$.  We did several mathematical experiments for $ds = 0.20, ds = 0.10, ds = 0.05, $ and $ds = 0.10$.
#
# We extended this work to include estimates for the changes $V = s^3, Q = s^7,$ and $p = \sqrt{s} = s^{0.5}$, finding expressions for $dV, dQ,$ and $dp$.
#
# In this activity, you'll work with a partner to handle three functions from the following list:
#
# | List A          |  List B           | List C              | List D          |
# |-----------------|-------------------|---------------------|-----------------|
# | $$E=e^x$$       |$$L=\log(x)$$      |$$S=\sin(x) $$       |$$C=\cos(x)$$    |
# | $$F=e^{4x}$$    |$$M=-2\log(3x) $$  |$$T=2\sin(3x + 5) $$ |$$D=3\cos(2x-4)$$|
# | $$G=3e^{-2x-3}$$|$$N=3\log(0.5x) $$ |$$U=4\sin(-x + 6) $$ |$$B=-2\cos(4x)$$ |
#
# Like before, we will choose several different values of $dx$ to account for the change in $x$ for each function, arriving at en expression like
#
# $$  dE = ( \hspace{1cm} ) dx $$
#
# We're going to be a bit more efficient this time:  Instead of copying and pasting tables into Desmos four times, one for each small change, we'll do this all at once with a separate column in our spreadsheet for each small change $dx$.

# %% [markdown]
# # Spreadsheet set-up
#
#
# In the spreadsheeet, click on 'File' and 'Make a Copy'.  This will make a copy of your spreadsheet in a separate tab.  This is ok - it will be easier to work in that tab.  If it doesn't open in a new tab, copy the url and paste it into a new browser tab.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In the spreadsheet, you'll notice that we have four columns (one for each different $dx$), four columns (one each for the change in the function), and   a separate column for each change in x, a separate column

# %%
from IPython.display import IFrame
IFrame(src="https://docs.google.com/spreadsheets/d/1PPWkmVgjIHLLer1uLkh7UbWtrCN5ae3TTwuGF4YFD00/copy?usp=sharing", width=1200, height=375)
# Out:
#         <iframe
#             width="1200"
#             height="375"
#             src="https://docs.google.com/spreadsheets/d/1PPWkmVgjIHLLer1uLkh7UbWtrCN5ae3TTwuGF4YFD00/edit?usp=sharing"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame(src="https://www.desmos.com/calculator/acfpj6uls0", width=1200, height=875)
# Out:
#         <iframe
#             width="1200"
#             height="875"
#             src="https://www.desmos.com/calculator/acfpj6uls0"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Now, repeat this again for the other functions in your list.

# %% [markdown]
# #Record your data and Save to Github:
#
# We'll make a record of our data in the following table.
#
# To add your data, double click your mouse in the cell, and then either modify the existing table row, or add a new table row.  Use | to separate columns, a new line for a new row, and --- to put a horizontal line in the table.
#
# Then, save this file out to your github account.

# %% [markdown]
# # HW List A:  Relationship for exponential functions
#
# Part 1:
#
# | Type of Data | $dx$ |    Equation for $d(e^x)$ $      |
# |--------------|------|-----------------------------|
# |  Experiment  | 0.2  | $$d(e^x) = (     ) ( 0.2)$$   |
# |  Experiment  | 0.1  | $$d(e^x) = (     ) ( 0.1)$$   |
# |  Experiment  | 0.05  | $$d(e^x) = (    ) ( 0.05)$$  |
# |  Experiment  | 0.01  | $$d(e^x) = (    ) ( 0.01)$$   |
# |--------------|-------|-----------------------------|
#
# So, as $dx$ shrinks toward $0$, our logical guess is:
# $$d(e^x) = (    ) ( dx )$$

# %% [markdown]
# Part 2:
#
# | Type of Data | $dx$ |    Equation for $d(e^x)$ $      |
# |--------------|------|-----------------------------|
# |  Experiment  | 0.2  | $$d(e^{4x}) = (     ) ( 0.2)$$   |
# |  Experiment  | 0.1  | $$d(e^{4x}) = (     ) ( 0.1)$$   |
# |  Experiment  | 0.05  | $$d(e^{4x}) = (     ) ( 0.05)$$   |
# |  Experiment  | 0.01  | $$d(e^{4x}) = (     ) ( 0.01)$$   |
# |--------------|-------|-----------------------------|
#
# So, as $dx$ shrinks toward $0$, our logical guess is:
# $$d(e^{4x}) = (     ) ( dx)$$

# %% [markdown]
# Part 3:
#
# | Type of Data | $dx$ |    Equation for $d(e^x)$ $      |
# |--------------|------|-----------------------------|
# |  Experiment  | 0.2  | $$d(3e^{-2x-3}) = (     ) ( 0.2)$$   |
# |  Experiment  | 0.1  | $$d(3e^{-2x-3}) = (     ) ( 0.1)$$   |
# |  Experiment  | 0.05  | $$d(3e^{-2x-3}) = (     ) ( 0.05)$$   |
# |  Experiment  | 0.01  | $$d(3e^{-2x-3}) = (     ) ( 0.01)$$   |
# |--------------|-------|-----------------------------|
#
# So, as $dx$ shrinks toward $0$, our logical guess is:
# $$d(3e^{-2x-3}) = (     ) ( dx)$$

# %% [markdown]
# # HW List B:  Relationship for exponential functions
#
# Part 1:
#
# | Type of Data | $dx$ |    Equation for $d(e^x)$ $      |
# |--------------|------|-----------------------------|
# |  Experiment  | 0.2  | $$d(\log(x)) = (     ) ( 0.2)$$   |
# |  Experiment  | 0.1  | $$d(\log(x)) = (     ) ( 0.1)$$   |
# |  Experiment  | 0.05  | $$d(\log(x)) = (    ) ( 0.05)$$  |
# |  Experiment  | 0.01  | $$d(\log(x)) = (    ) ( 0.01)$$   |
# |--------------|-------|-----------------------------|
#
# So, as $dx$ shrinks toward $0$, our logical guess is:
# $$d(\log(x)) = (    ) ( dx )$$

# %% [markdown]
# Part 2:
#
# | Type of Data | $dx$ |    Equation for $d(e^x)$ $      |
# |--------------|------|-----------------------------|
# |  Experiment  | 0.2  | $$d(-2\log(3x)) = (     ) ( 0.2)$$   |
# |  Experiment  | 0.1  | $$d(-2\log(3x)) = (     ) ( 0.1)$$   |
# |  Experiment  | 0.05  | $$d(-2\log(3x)) = (    ) ( 0.05)$$  |
# |  Experiment  | 0.01  | $$d(-2\log(3x)) = (    ) ( 0.01)$$   |
# |--------------|-------|-----------------------------|
#
# So, as $dx$ shrinks toward $0$, our logical guess is:
# $$d(-2\log(3x)) = (    ) ( dx )$$

# %% [markdown]
# Part 3:
#
# | Type of Data | $dx$ |    Equation for $d(e^x)$ $      |
# |--------------|------|-----------------------------|
# |  Experiment  | 0.2  | $$d(3\log(0.5x)) = (     ) ( 0.2)$$   |
# |  Experiment  | 0.1  | $$d(3\log(0.5x)) = (     ) ( 0.1)$$   |
# |  Experiment  | 0.05  | $$d(3\log(0.5x)) = (    ) ( 0.05)$$  |
# |  Experiment  | 0.01  | $$d(3\log(0.5x)) = (    ) ( 0.01)$$   |
# |--------------|-------|-----------------------------|
#
# So, as $dx$ shrinks toward $0$, our logical guess is:
# $$d(3\log(0.5x)) = (    ) ( dx )$$

# %% [markdown]
# # HW List c:  Relationship for exponential functions
#
# Part 1:
#
# | Type of Data | $dx$ |    Equation for $d(e^x)$ $      |
# |--------------|------|-----------------------------|
# |  Experiment  | 0.2  | $$d(\sin(x)) = (     ) ( 0.2)$$   |
# |  Experiment  | 0.1  | $$d(\sin(x)) = (     ) ( 0.1)$$   |
# |  Experiment  | 0.05  | $$d(\sin(x)) = (    ) ( 0.05)$$  |
# |  Experiment  | 0.01  | $$d(\sin(x)) = (    ) ( 0.01)$$   |
# |--------------|-------|-----------------------------|
#
# So, as $dx$ shrinks toward $0$, our logical guess is:
# $$d(\sin(x)) = (    ) ( dx )$$

# %% [markdown]
# Part 2:
#
# | Type of Data | $dx$ |    Equation for $d(e^x)$ $      |
# |--------------|------|-----------------------------|
# |  Experiment  | 0.2  | $$d(2\sin(3x+5)) = (     ) ( 0.2)$$   |
# |  Experiment  | 0.1  | $$d(2\sin(3x+5)) = (     ) ( 0.1)$$   |
# |  Experiment  | 0.05  | $$d(2\sin(3x+5)) = (    ) ( 0.05)$$  |
# |  Experiment  | 0.01  | $$d(2\sin(3x+5)) = (    ) ( 0.01)$$   |
# |--------------|-------|-----------------------------|
#
# So, as $dx$ shrinks toward $0$, our logical guess is:
# $$d(2\sin(3x+5)) = (    ) ( dx )$$

# %% [markdown]
# Part 3:
#
# | Type of Data | $dx$ |    Equation for $d(e^x)$ $      |
# |--------------|------|-----------------------------|
# |  Experiment  | 0.2  | $$d(4\sin(-x+6)) = (     ) ( 0.2)$$   |
# |  Experiment  | 0.1  | $$d(4\sin(-x+6)) = (     ) ( 0.1)$$   |
# |  Experiment  | 0.05  | $$d(4\sin(-x+6)) = (    ) ( 0.05)$$  |
# |  Experiment  | 0.01  | $$d(4\sin(-x+6)) = (    ) ( 0.01)$$   |
# |--------------|-------|-----------------------------|
#
# So, as $dx$ shrinks toward $0$, our logical guess is:
# $$d(4\sin(-x+6)) = (    ) ( dx )$$

# %% [markdown]
# # HW List D:  Relationship for exponential functions
#
# Part 1:
#
# | Type of Data | $dx$ |    Equation for $d(e^x)$ $      |
# |--------------|------|-----------------------------|
# |  Experiment  | 0.2  | $$d(\cos(x)) = (     ) ( 0.2)$$   |
# |  Experiment  | 0.1  | $$d(\cos(x)) = (     ) ( 0.1)$$   |
# |  Experiment  | 0.05  | $$d(\cos(x)) = (    ) ( 0.05)$$  |
# |  Experiment  | 0.01  | $$d(\cos(x)) = (    ) ( 0.01)$$   |
# |--------------|-------|-----------------------------|
#
# So, as $dx$ shrinks toward $0$, our logical guess is:
# $$d(\cos(x)) = (    ) ( dx )$$

# %% [markdown]
# Part 2:
#
# | Type of Data | $dx$ |    Equation for $d(e^x)$ $      |
# |--------------|------|-----------------------------|
# |  Experiment  | 0.2  | $$d(3\cos(2x-4)) = (     ) ( 0.2)$$   |
# |  Experiment  | 0.1  | $$d(3\cos(2x-4)) = (     ) ( 0.1)$$   |
# |  Experiment  | 0.05  | $$d(3\cos(2x-4)) = (    ) ( 0.05)$$  |
# |  Experiment  | 0.01  | $$d(3\cos(2x-4)) = (    ) ( 0.01)$$   |
# |--------------|-------|-----------------------------|
#
# So, as $dx$ shrinks toward $0$, our logical guess is:
# $$d(3\cos(2x-4)) = (    ) ( dx )$$

# %% [markdown]
# Part 3:
#
# | Type of Data | $dx$ |    Equation for $d(e^x)$ $      |
# |--------------|------|-----------------------------|
# |  Experiment  | 0.2  | $$d(-2\cos(4x)) = (     ) ( 0.2)$$   |
# |  Experiment  | 0.1  | $$d(-2\cos(4x)) = (     ) ( 0.1)$$   |
# |  Experiment  | 0.05  | $$d(-2\cos(4x)) = (    ) ( 0.05)$$  |
# |  Experiment  | 0.01  | $$d(-2\cos(4x)) = (    ) ( 0.01)$$   |
# |--------------|-------|-----------------------------|
#
# So, as $dx$ shrinks toward $0$, our logical guess is:
# $$d(-2\cos(4x)) = (    ) ( dx )$$
